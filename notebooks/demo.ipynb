# %% [markdown]
# # PAYBACK Lightweight Assistant — Demo
# Five distinct queries (different **languages** and **intents**) against the live Cloud Run service `https://payback-assistant-506488371374.europe-west3.run.app`, showing the raw JSON responses.
#
# | # | Query | Language | Expected intent / action |
# |---|---|---|---|
# | 1 | Bitte zeige mir Angebote für günstige Windeln | de | search → recommend |
# | 2 | I need stuff for a pasta dinner | en | discovery → theme basket |
# | 3 | Suche Shampoo bei dm | de | navigational → route_to_partner |
# | 4 | Was ist besser: Bio-Olivenöl oder normales Olivenöl? | de | comparison → compare |
# | 5 | Ich habe ein Problem mit meinen PAYBACK Punkten | de | customer_support → handoff |

# %%
import json, requests
BASE = 'https://payback-assistant-506488371374.europe-west3.run.app'
def ask(query, user_id='demo-notebook'):
    r = requests.post(f'{BASE}/assist', json={'query': query, 'user_id': user_id}, timeout=60)
    r.raise_for_status()
    print(json.dumps(r.json(), ensure_ascii=False, indent=2))
print('service:', requests.get(f'{BASE}/health', timeout=30).json())
# Out:
# service: {'status': 'ok', 'version': '1.0.0', 'products': 97, 'llm': 'gemini-2.5-flash-lite'}

# %% [markdown]
# ## 1 — German · search (price-aware)

# %%
ask('Bitte zeige mir Angebote für günstige Windeln')
# Out:
# {
#   "query": "Bitte zeige mir Angebote für günstige Windeln",
#   "language": "de",
#   "intent": "search",
#   "confidence": 0.85,
#   "action": {
#     "type": "recommend",
#     "detail": "Suchergebnisse über alle Partner-Kataloge."
#   },
#   "partner_filter": null,
#   "products": [
#     {
#       "id": "dm-001",
#       "partner": "dm",
#       "name": "Windeln Größe 4 Maxi",
#       "brand": "babylove",
#       "category": "Baby & Kind",
#       "price": 5.02,
#       "unit": "42 St",
#       "tags": [
#         "windeln",
#         "diapers",
#         "baby",
#         "wickeln"
#       ],
#       "score": 7.096
#     }
#   ],
#   "clarifying_question": null,
#   "engine": "rules",
#   "user_context": {
#     "user_id": "demo-notebook",
#     "interests": {
#       "Baby & Kind": 100.0
#     }
#   },
#   "latency_ms": 1.39
# }

# %% [markdown]
# ## 2 — English · discovery (theme basket across partners)

# %%
ask('I need stuff for a pasta dinner')
# Out:
# {
#   "query": "I need stuff for a pasta dinner",
#   "language": "en",
#   "intent": "search",
#   "confidence": 0.8,
#   "action": {
#     "type": "recommend",
#     "detail": "Search results across all partner catalogs."
#   },
#   "partner_filter": null,
#   "products": [
#     {
#       "id": "edeka-020",
#       "partner": "edeka",
#       "name": "Spaghetti No.5",
#       "brand": "EDEKA Italia",
#       "category": "Nudeln & Trockensortiment",
#       "price": 0.95,
#       "unit": "500 g",
#       "tags": [
#         "spaghetti",
#         "nudeln",
#         "pasta"
#       ],
#       "score": 7.159
#     },
#     {
#       "id": "edeka-021",
#       "partner": "edeka",
#       "name": "Penne Rigate",
#       "brand": "EDEKA Italia",
#       "category": "Nudeln & Trockensortiment",
#       "price": 0.96,
#       "unit": "500 g",
#       "tags": [
#         "penne",
#         "nudeln",
#         "pasta"
#       ],
#       "score": 6.883
#     },
#     {
#       "id": "edeka-022",
#       "partner": "edeka",
#       "name": "Basmati Reis",
#       "brand": "EDEKA",
#       "category": "Nudeln & Trockensortiment",
#       "price": 2.39,
#       "unit": "1 kg",
#       "tags": [
#         "reis",
#         "rice"
#       ],
#       "score": 3.649
#     },
#     {
#       "id": "amazon-010",
#       "partner": "amazon",
#       "name": "Kochbuch Pasta Amore",
#       "brand": "GU Verlag",
#       "category": "Bücher & Medien",
#       "price": 26.03,
#       "unit": "1 St",
#       "tags": [
#         "kochbuch",
#         "cookbook",
#         "pasta",
#         "buch",
#         "kochen"
#       ],
#       "score": 3.5
#     },
#     {
#       "id": "edeka-015",
#       "partner": "edeka",
#       "name": "Mozzarella",
#       "brand": "EDEKA Italia",
#       "category": "Käse",
#       "price": 1.0,
#       "unit": "125 g",
#       "tags": [
#         "mozzarella",
#         "käse",
#         "cheese",
#         "pasta"
#       ],
#       "score": 3.066
#     }
#   ],
#   "clarifying_question": null,
#   "engine": "rules+gemini-2.5-flash-lite@vertex-ai",
#   "user_context": {
#     "user_id": "demo-notebook",
#     "interests": {
#       "Nudeln & Trockensortiment": 50.0,
#       "Baby & Kind": 16.7,
#       "Bücher & Medien": 16.7,
#       "Käse": 16.7
#     }
#   },
#   "latency_ms": 460.09
# }

# %% [markdown]
# ## 3 — German · navigational (partner-scoped route)

# %%
ask('Suche Shampoo bei dm')
# Out:
# {
#   "query": "Suche Shampoo bei dm",
#   "language": "de",
#   "intent": "search",
#   "confidence": 0.85,
#   "action": {
#     "type": "route_to_partner",
#     "detail": "Weiterleitung zur Partner-Suche: dm."
#   },
#   "partner_filter": "dm",
#   "products": [
#     {
#       "id": "dm-005",
#       "partner": "dm",
#       "name": "Shampoo Repair & Care",
#       "brand": "Balea",
#       "category": "Haarpflege",
#       "price": 2.0,
#       "unit": "300 ml",
#       "tags": [
#         "shampoo",
#         "haare",
#         "hair"
#       ],
#       "score": 7.311
#     }
#   ],
#   "clarifying_question": null,
#   "engine": "rules",
#   "user_context": {
#     "user_id": "demo-notebook",
#     "interests": {
#       "Nudeln & Trockensortiment": 42.9,
#       "Baby & Kind": 14.3,
#       "Bücher & Medien": 14.3,
#       "Käse": 14.3,
#       "Haarpflege": 14.3
#     }
#   },
#   "latency_ms": 0.87
# }

# %% [markdown]
# ## 4 — German · comparison

# %%
ask('Was ist besser: Bio-Olivenöl oder normales Olivenöl?')
# Out:
# {
#   "query": "Was ist besser: Bio-Olivenöl oder normales Olivenöl?",
#   "language": "de",
#   "intent": "comparison",
#   "confidence": 0.8,
#   "action": {
#     "type": "compare",
#     "detail": "Vergleich der besten Treffer über alle Partner (Preis pro Einheit beachten)."
#   },
#   "partner_filter": null,
#   "products": [
#     {
#       "id": "edeka-024",
#       "partner": "edeka",
#       "name": "Olivenöl Extra Vergine",
#       "brand": "EDEKA Bio",
#       "category": "Konserven & Saucen",
#       "price": 7.08,
#       "unit": "500 ml",
#       "tags": [
#         "olivenöl",
#         "olive oil",
#         "bio",
#         "organic",
#         "pasta"
#       ],
#       "score": 10.814
#     },
#     {
#       "id": "edeka-012",
#       "partner": "edeka",
#       "name": "Bio-Eier Freiland",
#       "brand": "EDEKA Bio",
#       "category": "Molkerei & Eier",
#       "price": 3.4,
#       "unit": "10 St",
#       "tags": [
#         "eier",
#         "eggs",
#         "bio",
#         "organic"
#       ],
#       "score": 5.354
#     },
#     {
#       "id": "edeka-011",
#       "partner": "edeka",
#       "name": "Bio-Joghurt Natur",
#       "brand": "EDEKA Bio",
#       "category": "Molkerei & Eier",
#       "price": 1.0,
#       "unit": "500 g",
#       "tags": [
#         "joghurt",
#         "yogurt",
#         "bio",
#         "organic"
#       ],
#       "score": 5.306
#     },
#     {
#       "id": "edeka-035",
#       "partner": "edeka",
#       "name": "Bio-Honig",
#       "brand": "EDEKA Bio",
#       "category": "Frühstück",
#       "price": 4.44,
#       "unit": "500 g",
#       "tags": [
#         "honig",
#         "honey",
#         "bio",
#         "organic",
#         "frühstück"
#       ],
#       "score": 5.301
#     },
#     {
#       "id": "dm-003",
#       "partner": "dm",
#       "name": "Babybrei Pastinake",
#       "brand": "dmBio",
#       "category": "Baby & Kind",
#       "price": 1.12,
#       "unit": "190 g",
#       "tags": [
#         "babybrei",
#         "baby food",
#         "bio",
#         "organic"
#       ],
#       "score": 3.941
#     }
#   ],
#   "clarifying_question": null,
#   "engine": "rules",
#   "user_context": {
#     "user_id": "demo-notebook",
#     "interests": {
#       "Nudeln & Trockensortiment": 25.0,
#       "Baby & Kind": 16.7,
#       "Molkerei & Eier": 16.7,
#       "Bücher & Medien": 8.3,
#       "Käse": 8.3,
#       "Haarpflege": 8.3,
#       "Konserven & Saucen": 8.3,
#       "Frühstück": 8.3
#     }
#   },
#   "latency_ms": 1.97
# }

# %% [markdown]
# ## 5 — German · customer support (handoff, no products)

# %%
ask('Ich habe ein Problem mit meinen PAYBACK Punkten')
# Out:
# {
#   "query": "Ich habe ein Problem mit meinen PAYBACK Punkten",
#   "language": "de",
#   "intent": "customer_support",
#   "confidence": 0.9,
#   "action": {
#     "type": "support_handoff",
#     "detail": "Das klingt nach einem Anliegen für unseren Kundenservice. Ich leite dich weiter: PAYBACK Service unter 089 / 996 331 60 oder im Hilfe-Center der App (Konto → Hilfe)."
#   },
#   "partner_filter": null,
#   "products": [],
#   "clarifying_question": null,
#   "engine": "rules",
#   "user_context": {
#     "user_id": "demo-notebook",
#     "interests": {
#       "Nudeln & Trockensortiment": 25.0,
#       "Baby & Kind": 16.7,
#       "Molkerei & Eier": 16.7,
#       "Bücher & Medien": 8.3,
#       "Käse": 8.3,
#       "Haarpflege": 8.3,
#       "Konserven & Saucen": 8.3,
#       "Frühstück": 8.3
#     }
#   },
#   "latency_ms": 0.32
# }

# %% [markdown]
# ### Bonus — LLM escalation + user context
# A paraphrase the lexicon cannot parse escalates to Gemini on Vertex AI; note the `engine` field and the `user_context` interest profile accumulated by the five queries above (fed to the LLM with 30% weight).

# %%
ask('Ich brauche etwas gegen wunden Po bei meinem Kleinkind')
# Out:
# {
#   "query": "Ich brauche etwas gegen wunden Po bei meinem Kleinkind",
#   "language": "de",
#   "intent": "search",
#   "confidence": 0.8,
#   "action": {
#     "type": "recommend",
#     "detail": "Suchergebnisse über alle Partner-Kataloge."
#   },
#   "partner_filter": null,
#   "products": [
#     {
#       "id": "dm-018",
#       "partner": "dm",
#       "name": "After Sun Lotion",
#       "brand": "Sundance",
#       "category": "Sonnenschutz",
#       "price": 3.28,
#       "unit": "200 ml",
#       "tags": [
#         "after sun",
#         "sonne",
#         "haut"
#       ],
#       "score": 5.244
#     },
#     {
#       "id": "dm-002",
#       "partner": "dm",
#       "name": "Feuchttücher Sensitiv",
#       "brand": "babylove",
#       "category": "Baby & Kind",
#       "price": 1.67,
#       "unit": "80 St",
#       "tags": [
#         "feuchttücher",
#         "wipes",
#         "baby"
#       ],
#       "score": 4.802
#     },
#     {
#       "id": "dm-010",
#       "partner": "dm",
#       "name": "Handcreme Kamille",
#       "brand": "Balea",
#       "category": "Körperpflege",
#       "price": 1.19,
#       "unit": "100 ml",
#       "tags": [
#         "handcreme",
#         "hand cream"
#       ],
#       "score": 4.719
#     },
#     {
#       "id": "dm-009",
#       "partner": "dm",
#       "name": "Bodylotion Urea",
#       "brand": "Balea",
#       "category": "Körperpflege",
#       "price": 2.23,
#       "unit": "400 ml",
#       "tags": [
#         "bodylotion",
#         "body lotion",
#         "haut"
#       ],
#       "score": 4.638
#     },
#     {
#       "id": "dm-003",
#       "partner": "dm",
#       "name": "Babybrei Pastinake",
#       "brand": "dmBio",
#       "category": "Baby & Kind",
#       "price": 1.12,
#       "unit": "190 g",
#       "tags": [
#         "babybrei",
#         "baby food",
#         "bio",
#         "organic"
#       ],
#       "score": 4.57
#     }
#   ],
#   "clarifying_question": null,
#   "engine": "rules+gemini-2.5-flash-lite@vertex-ai",
#   "user_context": {
#     "user_id": "demo-notebook",
#     "interests": {
#       "Baby & Kind": 23.5,
#       "Nudeln & Trockensortiment": 17.6,
#       "Molkerei & Eier": 11.8,
#       "Körperpflege": 11.8,
#       "Bücher & Medien": 5.9,
#       "Käse": 5.9,
#       "Haarpflege": 5.9,
#       "Konserven & Saucen": 5.9,
#       "Frühstück": 5.9,
#       "Sonnenschutz": 5.9
#     }
#   },
#   "latency_ms": 501.65
# }

# %% [markdown]
# ### Bonus — engine modes: `off` (rules only) vs `always` (LLM on every query)
# Same query through both engines. Rules answer known vocabulary in ~1–2 ms server-side; the optimized LLM path (thinking disabled, compact schema, regional Vertex endpoint — see [/optimization-report](/optimization-report)) adds ~0.4 s. `llm_mode` and `model` are per-request API fields.

# %%
import uuid, requests as rq
q = f'Sussigkeiten und Pizza {uuid.uuid4().hex[:6]}'  # nonce avoids the response cache
for mode in ('off', 'always'):
    d = rq.post(f'{BASE}/assist', json={'query': q, 'llm_mode': mode,
                'user_id': 'demo-modes'}, timeout=60).json()
    tops = ', '.join(p['name'] for p in d['products'][:3])
    print(f"llm_mode={mode:6} server={d['latency_ms']:7.1f} ms  engine={d['engine']}")
    print(f'  -> {tops}')
# Out:
# llm_mode=off    server=    1.3 ms  engine=rules
#   -> Tiefkühlpizza Salami, Schokolade Vollmilch, Gummibärchen Goldbären
# llm_mode=always server=  426.1 ms  engine=rules+gemini-2.5-flash-lite@vertex-ai
#   -> Tiefkühlpizza Salami, Gummibärchen Goldbären, Schokolade Vollmilch
